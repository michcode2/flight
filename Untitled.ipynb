# %%
import numpy as np
import matplotlib.pyplot as plt 
# %config InlineBackend.figure_format = 'retina'
import pandas as pd

# %%
data = pd.read_csv("log.log")
[plt.plot(data[c][:], label=c) for c in data.columns[:]]
plt.legend()

# %%
plt.plot(data["lift"][4100:])
max(data["lift"])
plt.grid()

# %%
things = range(0,len(data["alpha"]))
plt.plot(data["alpha"][things], label = "alpha")

# %%
plt.plot(data["z vel"])

# %%
plt.plot(data["x vel"])

# %%
plt.scatter(data["z pos"], data["rho"])
